# %%
def montant_positif():
    while True:
        amount = input("Please enter a positive amount")
        try:
            number = float(amount)

            if number >= 0:
                print(f"Perfect, you have chosen: {number} as amount")
                return number
            else:
                print("Error: The amount must be positive.")
        except:
            print("Error, please enter a number not a text")

# %%
montant_positif()
# Out:
# Error, please enter a number not a text
# Error: The amount must be positive.
# Perfect, you have chosen: 6.0 as amount
# 6.0
