# %%
def montant_positif():
    number = float(input("Please enter a positive amount"))
    while number<0:
        print("Error, please enter a positive amount")
        number = float(input("Please enter a positive amount"))
    print(f"Perfect, you have choosen : {number} as amount")
    return number
